# %%
#Illustrating different set operations 
E = {0,2,4,8,6}
N = {1,2,3,4,5}

Union = E | N
print (Union)

Intersection = E & N
print (Intersection)

Difference = E - N
print (Difference)

Symmetrical_Difference = E ^ N
print (Symmetrical_Difference)
# Out:
# {0, 1, 2, 3, 4, 5, 6, 8}
# {2, 4}
# {0, 8, 6}
# {0, 1, 3, 5, 6, 8}
